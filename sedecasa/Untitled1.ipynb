# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
A = 1
k = (2*math.pi)/0.3

# %%
def f(x):
    return math.sqrt((x-x_0)**2 + (y-y_0)**2)

# %%
def W(A=1, k=(2*math.pi)/0.3):
    return A*math.sin(k*abs(f(x)))

# %%
def plot(xs, ys):
    plt.xlabel('x')
    plt.ylabel('y')
    plt.plot()

xs = [i for i in range(-4, 4)]
ys = [i for i in range(-4, 4)]
