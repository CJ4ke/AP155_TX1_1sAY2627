# %% [markdown]
# Plot sinx+x

# %%
import numpy as np
import matplotlib.pyplot as plt
def function():
    return np.sin(x)+x
plt.plot(np.linspace, function)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       3 def function():
#       4     return np.sin(x)+x
# ----> 5 plt.plot(np.linspace, func)
#
# NameError: name 'func' is not defined

# %% [markdown]
# Make variable w name print name

# %%
name = 'Judiele'
print('Hello my name is ' + name)
# Out:
# Hello my name is Judiele
