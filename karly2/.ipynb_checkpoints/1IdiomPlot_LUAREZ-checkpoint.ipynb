# %% [markdown]
# # AP 155 Lab Exercise
# ---
# ## Exercise 1: Idiomatic Python
#
# _Instructions_:
# - **Report figure (Problem 1):** Plot the 2D wave interference pattern between 2 (or more) coherent sources. Include at least 1 figure.
# - **Report discussion (Problem 2):** Write a custom `matrix_multiply()`function using Python list comprehensions without external libraries (do not use `np.dot()` or `@`).
#     - (i) For larger matrices, which is preferred, the custom `matrix_multiply()` or the `@` operator... why?
#     - (ii) What are the general benefits of writing idiomatic Python?
# - **Code**: Complete the codes and ensure they are functional, error-free, readable, and efficient (where needed). Include a concise markdown documentation highlighting the critical steps of your algorithm for each problem.
#
# ### Student Information
# - _Full Name (Last Name, First Name)_: Luarez, Karl Andrei
# - _Student No._: 2024-12430
# - _Section_: THU-TX1
#
# ### Grading Information (c/o Lab Instructor)
# - [Rubrics description link](https://drive.google.com/file/d/1G9tPPcyMUag91g_R02O0wsGYPiZWy5Nn/view?usp=drive_link) (Note: percentages may still be tweaked)
#
# | Criteria | Score | Subtotal |
# | --- | --- | --- |
# | Report figure | XX | 20 |
# | Report discussion | XX | 20|
# | Code readability | XX | 20 |
# | Code efficiency | XX | 20 |
# | Code appropriateness  | XX | 20 |
# | **TOTAL** | XXX | 100 |
#
# _Date and Time Scored (MM/DD/YYYY HH:MM AM/PM):_:_

# %% [markdown]
# ---
# ## Section 1: Report

# %% [markdown]
# ### Problem 1
#
# ![2DInterference.png](attachment:b92b421b-040c-47e8-ab3a-a4619db2619b.png)
#
# The figure describes the interference pattern generated by two point sources as modelled by the equation in Problem 1.
#
# ### Problem 2
# i) The @ NumPy operator is better than the matrix_multiply() function we created using Python for matrix multiplication especially for larger matrices because it is a built-in function whereas the matrix_multiply() function uses list comprehensions which could slow down calculations.
# ii) In general, coding idiomatically with python allows for a more efficient and easily readable script using native features in python. This makes way for a faster and cleaner coding.
#
#
#
# ### Other comments
# - EDIT ME
# - A self reflection can be placed here.
# - This portion is not graded.
# - You may insert further questions here.

# %% [markdown]
# ---
# ## Section 2: Code

# %% [markdown]
# ### Problem 1: 2D Wave interference (Gezerlis Problem 1.15)

# %% [markdown]
# Assume that the combined eﬀect of two objects dropped in a water basin can be modelled by:
# $$ W(\textbf{r}) = A \sin (k|\textbf{r}-\textbf{r}_0|) + A  \sin (k|\textbf{r}-\textbf{r}_1|). $$ You can think of this as an updated version of Eq. (1.3) in the book, where we are dealing with the linear addition of sinusoidal waves, instead of electric-field contributions. For simplicity, take $A=1$, $k=2\pi/0.3$, $r_0 = (−1, 0)$ , and $r_1 = (1, 0)$. Since we are now faced with a density plot, you should employ, NOT `streamplot()` but, `imshow()` from `Matplotlib`; in each of $x$ and $y$ your plot should extend from $−4$ to $+4$.

# %%
import matplotlib.pyplot as plt
import numpy as np

A = 1
k = 2*np.pi/0.3
r0 = (-1,0)
r1 = (1,0)

# modeling the wave interference
def water_model(xs, ys):
    droppos = {(-1,0), (1,0)} # position of water droplets
    n = len(xs) 
    Ws = [[0. for l in range(n)] for j in range (n)]
    for j, x in enumerate(xs): # looping over all x and y
            for l, y in enumerate(ys):
                for pos in droppos:
                    posx, posy = pos
                    R = np.sqrt((x-posx)**2 + (y-posy)**2)
                    Ws[l][j]+= A*np.sin(k*abs(R)) #putting the values in the model
    return Ws

def plotwater(box1, n): 
    xs = [-box1 + i*2*box1/(n-1) for i in range(n)]
    ys = xs[:]
    Ws = water_model(xs, ys)
    xs = np.array(xs); ys = np.array(ys)
    Ws = np.array(Ws)
    plt.xlabel('$x$')
    plt.ylabel('$y$')
    plt.title('2D Wave Interference')
    
    plt.imshow(Ws, extent = [-4, 4, -4, 4])

    plt.savefig("2DInterference.png")
    
fig = plotwater(4.,800)

# %% [markdown]
# #### Problem 1 code summary
#
# The code sketches a 2D wave interference pattern from two point sources by using list comprehensions and iterations using loops over every point in the grid. This allows it to calculate the model over every point in the grid.
# ---

# %% [markdown]
# ### Problem 2: Listcomps-maxxing

# %% [markdown]
# Import the `random` library (docs: https://docs.python.org/3/library/random.html). We will be using the `random.randint` function to pick random integers.

# %%
import random
number = random.randint(1, 9)
number
# Out:
# 8

# %% [markdown]
# a. Create a function `random_integer_matrix(nrows, ncols)` that generates a matrix in the form of "list-of-lists" whose elements are random integers from $1$ to $9$. Each "sub-list" inside the main list is a row in the matrix.

# %%
def random_integer_matrix(nrows, ncols):
    matrix = [[random.randint(1,9) for k in range(ncols)] for i in range(nrows)] #creates a matrix of n rows and columns 
    return matrix

random_integer_matrix(3, 4)
# Out:
# [[1, 4, 7, 6], [8, 5, 6, 6], [7, 9, 7, 5]]

# %% [markdown]
# b. Create a function `scalar_product(list1, list2)` where you multiply each element at the same index in the two lists and sum/accumulate the results.

# %%
def scalar_product(list_1, list_2):
    dot = 0
    if len(list_1) == len(list_2):
        for i in range(len(list_1)): 
           dot += list_1[i]*list_2[i] #multiplies elements of the same index in the list and sums it up
        return dot
    else: print('Invalid input')

# %%
A= [1,2,3]
B = [2,3,4]

scalar_product(A,B)
# Out:
# 20

# %% [markdown]
# c. Create a function `transpose_matrix(orig_matrix)` which returns the transpose of any matrix also in "list-of-lists" form. Do not assume the size of the matrix; figure it out within the function. Double-check that your implementations above work. Create a $3\times4$ random integer matrix, print it out and its transpose. The values and shape between the two should be consistent.

# %%
mat = random_integer_matrix(4,3)

def transpose_matrix(ogmatrix):
    return [[ogmatrix[j][i] for j in range(len(ogmatrix))] # takes the value of row j and column i in the orig matrix as elements of the row of the new matrix
            for i in range(len(ogmatrix[0]))] # takes the no. of elements of the first list (row) to be the no. of columns of the new matrix

print(f"Original matrix: {mat}")
print(f"Transposed matrix: :{transpose_matrix(mat)}")
# Out:
# Original matrix: [[2, 3, 7], [4, 3, 9], [1, 9, 9], [7, 2, 2]]
# Transposed matrix: :[[2, 4, 1, 7], [3, 3, 9, 2], [7, 9, 9, 2]]

# %% [markdown]
# d. Create a function `matrix_multiply(left_matrix, right_matrix)` which performs the matrix multiplication. Do not assume the matrices follow a specific shape. Here's some tips and strategies:
# * Determine how many rows and columns the left and right matrices have. Which numbers should match in order for us to have valid matrix multiplication?
# * Iterating the elements of "list-of-lists" gives us the rows, but we need to iterate the columns for the right matrix.
# * Use the `transpose_matrix` function, then iteratively apply `scalar_product`.

# %%
def matrix_multiply(left_matrix, right_matrix):
    if len(left_matrix[0]) != len(right_matrix): # Column left not equal to rows right
        print("Operation invalid")
    else :
        transposed_right = transpose_matrix(right_matrix) # Transpose right matrix to access columns easily
        matrixmult = [] 
        for rows in left_matrix:
            row = []
            for columns in right_matrix:
                row.append(scalar_product(rows, columns)) #element of the new matrix's row is the scalar product of the left nth row and right nth column
            matrixmult.append(row) #plug in new rows to the new matrix

    return matrixmult
            
        
A = [[1,1],[1,1]]; B = [[2,2],[2,2]]
print(matrix_multiply(A,B))
# Out:
# [[4, 4], [4, 4]]

# %% [markdown]
# #### Problem 2 code summary
#
# The scripts above performs several matrix operations using only python idioms and list comprehensions. Using for loops and list comprehensions allows the required element by element calculations to perform the needed matrix operation.
