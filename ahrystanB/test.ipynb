# %%
import matplotlib.pyplot as plt
import numpy as np
def f(x):
    return np.sin(x) + x
x1 = np.arange(-5, 5, 0.1)
y1 = np.arange(-5, 5, 0.2)

plt.figure()
plt.plot(x1, f(x1), 'k')

# %%
a = "Ahrystan"
print("Hello my name is " + a)
# Out:
# Hello my name is Ahrystan
