# %%
import matplotlib.pyplot as plt
import numpy as np

def function(x):
    return np.sin(x) + x

x = np.linspace(-5, 5, 100)
y = function(x)

plt.plot(x, y, color = "blue")
plt.grid("True")
plt.title("$\sin(x) + x$")
# Out:
# Text(0.5, 1.0, '$\\sin(x) + x$')
