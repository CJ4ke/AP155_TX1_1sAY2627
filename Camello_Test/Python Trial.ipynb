# %%
Name = input("What is your name? ")
message = f"Hello {Name}!"
print(message)
# Out:
# What is your name?  Tes5t
# Hello Tes5t!

# %%
Name1 = input("Test: ")
print("Hello " + str(Name1) + " !")
# Out:
# Test:  et45re
# Hello et45re !
